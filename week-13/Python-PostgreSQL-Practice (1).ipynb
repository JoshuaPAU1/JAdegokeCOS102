# %% [markdown]
# # Python - PostgreSQL

# %% [markdown]
# <ul><li>PostgreSQL can be integrated with Python using psycopg2 module.</li><li>psycopg2 is a PostgreSQL database adapter for the Python programming language.</li><li>psycopg2 was written with the aim of being very small and fast, and stable as a rock.</li><li> You do not need to install this module separately because it is shipped, by default, along with Python version 2.5.x onwards.</li></ul>

# %% [markdown]
# # Python psycopg2 Module APIs
#
# If you do not have it installed on your machine then you can use the command to install it as follows:

# %%
pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.9-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# Downloading psycopg2-2.9.9-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.2 MB 217.9 kB/s eta 0:00:06
#     --------------------------------------- 0.0/1.2 MB 217.9 kB/s eta 0:00:06
#     --------------------------------------- 0.0/1.2 MB 217.9 kB/s eta 0:00:06
#    - -------------------------------------- 0.0/1.2 MB 100.9 kB/s eta 0:00:12
#    - -------------------------------------- 0.0/1.2 MB 100.9 kB/s eta 0:00:12
#    - -------------------------------------- 0.0/1.2 MB 100.9 kB/s eta 0:00:12
#    - -------------------------------------- 0.0/1.2 MB 100.9 kB/s eta 0:00:12
#    - -------------------------------------- 0.0/1.2 MB 100.9 kB/s eta 0:00:12
#    - -------------------------------------- 0.0/1.2 MB 100.9 kB/s eta 0:00:12
#    - -------------------------------------- 0.0/1.2 MB 100.9 kB/s eta 0:00:12
#    - -------------------------------------- 0.0/1.2 MB 100.9 kB/s eta 0:00:12
#    - -------------------------------------- 0.0/1.2 MB 100.9 kB/s eta 0:00:12
#    - -------------------------------------- 0.0/1.2 MB 100.9 kB/s eta 0:00:12
#    - -------------------------------------- 0.0/1.2 MB 100.9 kB/s eta 0:00:12
#    --- ------------------------------------ 0.1/1.2 MB 142.4 kB/s eta 0:00:08
#    --- ------------------------------------ 0.1/1.2 MB 142.4 kB/s eta 0:00:08
#    --- ------------------------------------ 0.1/1.2 MB 142.4 kB/s eta 0:00:08
#    --- ------------------------------------ 0.1/1.2 MB 142.4 kB/s eta 0:00:08
#    --- ------------------------------------ 0.1/1.2 MB 142.4 kB/s eta 0:00:08
#    --- ------------------------------------ 0.1/1.2 MB 142.4 kB/s eta 0:00:08
#    --- ------------------------------------ 0.1/1.2 MB 142.4 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.1/1.2 MB 109.3 kB/s eta 0:00:10
#    ---- ----------------------------------- 0.1/1.2 MB 123.5 kB/s eta 0:00:09
#    ----- ---------------------------------- 0.2/1.2 MB 136.5 kB/s eta 0:00:08
#    ----- ---------------------------------- 0.2/1.2 MB 139.8 kB/s eta 0:00:08
#    ------- -------------------------------- 0.2/1.2 MB 157.7 kB/s eta 0:00:07
#    ------- -------------------------------- 0.2/1.2 MB 169.9 kB/s eta 0:00:06
#    -------- ------------------------------- 0.3/1.2 MB 182.9 kB/s eta 0:00:05
#    --------- ------------------------------ 0.3/1.2 MB 193.6 kB/s eta 0:00:05
#    --------- ------------------------------ 0.3/1.2 MB 193.6 kB/s eta 0:00:05
#    ---------------------------- ----------- 0.8/1.2 MB 264.8 kB/s eta 0:00:02
#    ------------------------------ --------- 0.9/1.2 MB 277.2 kB/s eta 0:00:02
#    ------------------------------ --------- 0.9/1.2 MB 277.6 kB/s eta 0:00:01
#    ------------------------------ --------- 0.9/1.2 MB 277.6 kB/s eta 0:00:01
#    -------------------------------- ------- 0.9/1.2 MB 283.6 kB/s eta 0:00:01
#    -------------------------------- ------- 0.9/1.2 MB 283.6 kB/s eta 0:00:01
#    -------------------------------- ------- 0.9/1.2 MB 283.6 kB/s eta 0:00:01
#    --------------------------------- ------ 1.0/1.2 MB 277.1 kB/s eta 0:00:01
#    --------------------------------- ------ 1.0/1.2 MB 277.1 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 284.2 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.0/1.2 MB 290.4 kB/s eta 0:00:01
#    ------------------------------------ --- 1.1/1.2 MB 295.1 kB/s eta 0:00:01
#    ------------------------------------ --- 1.1/1.2 MB 295.1 kB/s eta 0:00:01
#    ------------------------------------- -- 1.1/1.2 MB 294.4 kB/s eta 0:00:01
#    ---------------------------------------  1.1/1.2 MB 299.2 kB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 303.8 kB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The following are important psycopg2 module routines:

# %% [markdown]
# <table border=1 style="font-size:15px;">
#     <tr>
#         <td width=200><b>APIs</b></td><td width=800><b>Description</b></td>
#     </tr>
#     <tr>
#         <td>psycopg2.connect()</td><td>This API opens a connection to the PostgreSQL database.</td>
#     </tr>
#      <tr>
#         <td>connection.cursor()</td><td>This routine creates a cursor which will be used throughout of your database programming with Python.</td>
#     </tr>
#     <tr>
#         <td>cursor.execute()</td><td>This routine executes an SQL statement. The SQL statement may be parameterized (i.e., placeholders instead of SQL literals).</td>
#     </tr>
#      <tr>
#         <td>connection.close()</td><td>DescriptionThis method closes the database connection.</td>
#     </tr>
#     <tr>
#         <td>cursor.fetchone()</td><td>This method fetches the next row of a query result set, returning a single sequence, or None when no more data is available.</td>
#     </tr>
#      <tr>
#         <td>cursor.fetchall()</td><td>This routine fetches all (remaining) rows of a query result, returning a list. An empty list is returned when no rows are available.</td>
#     </tr>
#     <tr>
#         <td>psycopg2.connect()</td><td>This API opens a connection to the PostgreSQL database.</td>
#     </tr>
# </table>

# %% [markdown]
# # Connecting to a Database

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "postgres"
user = "postgres"
password = "cos101"

# Establish the connection
try:
    connections = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Execute a SQL query
    cursor.execute("SELECT version();")
    
    # Fetch and print the result of the query
    db_version = cursor.fetchone()
    print(f"PostgreSQL database version: {db_version}")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error connecting to PostgreSQL DB: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Error connecting to PostgreSQL DB: current transaction is aborted, commands ignored until end of transaction block

# %% [markdown]
# # Selecting existing Database

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "postgres"
user = "postgres"
password = "cos101"

# Establish the connection
try:
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL SELECT query
    select_query = "SELECT * FROM company;"

    # Execute the query
    cursor.execute(select_query)

    # Fetch all rows from the executed query
    data = cursor.fetchall()

    print("column1", " | ", "column2")
    print("------------------------")
        
    # Iterate through the rows and print them
    for row in data:
        print(f"{row[0]}       |  {row[1]}")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error connecting to PostgreSQL DB: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Error connecting to PostgreSQL DB: relation "company" does not exist
# LINE 1: SELECT * FROM company;
#                       ^

# %% [markdown]
# # Create a new Database

# %%
import psycopg2

# Parameters to connect to the existing PostgreSQL server
host = "localhost"
port = "5432"
dbname = "postgres"
user = "postgres"
password = "cos101"  # Connect to the default database

# Name of the new database to be created
new_dbname = "cos102_db"

try:
    # Connect to the PostgreSQL server
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL server successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new database
    create_db_query = f"CREATE DATABASE {new_dbname}"
    # Execute the SQL statement
    cursor.execute(create_db_query)
    print(f"Database '{new_dbname}' created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating the database: {error}")
# Out:
# Connection to PostgreSQL server successful
# Database 'cos102_db' created successfully

# %% [markdown]
# # Create a Table

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "cos102_db"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new table
    create_table_query = """
    CREATE TABLE sst_info (
        id SERIAL PRIMARY KEY,
        name VARCHAR(50) NOT NULL,
        age INT NOT NULL,
        department VARCHAR NOT NULL,
        password VARCHAR NOT NULL
    );
    """

    # Execute the SQL statement
    cursor.execute(create_table_query)
    print("Table created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating table: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Table created successfully

# %% [markdown]
# # INSERT into Table

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "cos102_db"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL INSERT statement
    insert_query = """
    INSERT INTO sst_info (id, name, age, department, password)
    VALUES (%s, %s, %s, %s, %s);
    """
    
    # Data to be inserted
    data_to_insert = (1, "Jamel Ojo", 20, "Software Engineering", "anthelo4")

    # Execute the SQL statement
    cursor.execute(insert_query, data_to_insert)
    print("Data inserted successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error inserting data: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Data inserted successfully

# %% [markdown]
# # SELECT from Table

# %%
import psycopg2

# Define your database connection parameters
db_params = {
    'dbname': 'cos102_db',
    'user': 'postgres',
    'password': 'cos101',
    'host': 'localhost',
    'port': '5432'  # Default is '5432'
}

try:
    # Establish a connection to the database
    connection = psycopg2.connect(**db_params)

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL query
    select_query = "SELECT * FROM sst_info WHERE age < 30"

    # Execute the SQL query
    cursor.execute(select_query)

    # Fetch all the results
    result = cursor.fetchall()

    # Print the results
    for row in result:
        print(row)

except Exception as error:
    print(f"Error while connecting to PostgreSQL: {error}")

finally:
    # Close the cursor and connection to clean up
    if cursor:
        cursor.close()
    if connection:
        connection.close()
# Out:
# (1, 'Jamel Ojo', 20, 'Software Engineering', 'anthelo4')

# %% [markdown]
# # Class Project I

# %% [markdown]
# Paystack is a Nigerian financial technology company that offers payment processing services to businesses. As a technology company, Paystack solves payment problems for ambitious businesses. Its mission is to help businesses in Africa become profitable, envied, and loved. They make it easy for businesses to accept secure payments from multiple local and global payment channels. They also provide tools to help you retain and acquire new customers. Currently, Paystack is restructuring the team network. It is a diverse, close-knit team on an adventure to build something enduring while learning something new, every day.

# %% [markdown]
# <img src="paystack.JPG">

# %% [markdown]
# With your knowledge in python programming develop an application that creates the database named <b>Paystack_Team</b>. <br>The purpose of the application is to enable management to perform the following queries:
# <ul>
#     <li>Team Members in Revenue Division</li>
#     <li>Team Members in Growth and Product Division whose age is greater than 30 years but less than 35 years</li>
#     <li>Team Members in Modules 1,3 and 5</li>
#     <li>Team Members in Modules 4 and Product Division</li>
# </ul>

# %%
import psycopg2

# Database connection parameters for creating the database
host = "localhost"
port = "5432"
user = "postgres"
password = "cos101"

# Connect to PostgreSQL to create the database
try:
    connection = psycopg2.connect(
        host=host,
        port=port,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Create the database
    cursor.execute("CREATE DATABASE paystack_team")
    print("Database paystack_team created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating database: {error}")

# Database connection parameters for paystack_team
dbname = "paystack_team"

# Connect to the newly created database to create the table and insert data
try:
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to paystack_team DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new table
    create_table_query = """
    CREATE TABLE staff_info (
        Name VARCHAR(255) PRIMARY KEY,
        Division VARCHAR(50) NOT NULL,
        Age INT NOT NULL,
        Module INT NOT NULL
    );
    """

    # Execute the SQL statement
    cursor.execute(create_table_query)
    print("Table staff_info created successfully")

    # Data to be inserted
    data_to_insert = [
        ("Oyinda Aina", "Business", 32, 1),
        ("Wale Eseyin", "Engineering", 28, 3),
        ("Khadijah Abu", "Product", 30, 2),
        ("Onyekachi Mbaike", "Design", 37, 5),
        ("Seike Ibojo", "Growth", 33, 4),
        ("Opemipo Aikomo", "Design", 28, 1),
        ("Ezra Olubi", "Product", 30, 3),
        ("Alexander Fasoro", "Engineering", 35, 1),
        ("Stephen Amaza", "Growth", 40, 2),
        ("Loknan Nanyak", "Engineering", 44, 5),
        ("Ibrahim Lawal", "Engineering", 39, 4),
        ("Fisayo Kolawole", "Commercial", 27, 5),
        ("Emmanuel Quartey", "Growth", 31, 1),
        ("Awatt Bassey", "Growth", 32, 2),
        ("Bolaji Akande", "Revenue", 30, 3),
        ("Mohini Ufeli", "Growth", 29, 2),
        ("King Makanjuola", "Product", 31, 1),
        ("Ijeoma Opara", "Revenue", 26, 2),
        ("Dipo Omobomi", "Product", 32, 1),
        ("Dapo Awobokun", "Revenue", 35, 2),
        ("Charles Idem", "Revenue", 38, 3),
        ("Ayobami Alo", "Product", 34, 1),
        ("Aminat Badara", "Growth", 30, 2)
    ]

    # Define the SQL INSERT statement
    insert_query = """
    INSERT INTO staff_info (Name, Division, Age, Module)
    VALUES (%s, %s, %s, %s);
    """

    # Execute the SQL statement for each row of data
    cursor.executemany(insert_query, data_to_insert)
    print("Data inserted successfully")

except Exception as error:
    print(f"Error creating table or inserting data: {error}")

finally:
    if cursor:
        cursor.close()
    if connection:
        connection.close()


# Functions to perform the specified queries

def connect_to_db():
    return psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )


def query_team_members_in_revenue():
    try:
        connection = connect_to_db()
        cursor = connection.cursor()
        cursor.execute("SELECT * FROM staff_info WHERE Division = 'Revenue'")
        results = cursor.fetchall()
        print("Team Members in Revenue Division:")
        for row in results:
            print(row)
    except Exception as error:
        print(f"Error querying team members in Revenue Division: {error}")
    finally:
        if cursor:
            cursor.close()
        if connection:
            connection.close()


def query_team_members_in_growth_and_product_age_30_35():
    try:
        connection = connect_to_db()
        cursor = connection.cursor()
        cursor.execute("""
            SELECT * FROM staff_info
            WHERE (Division = 'Growth' OR Division = 'Product') 
            AND Age > 30 AND Age < 35
        """)
        results = cursor.fetchall()
        print("Team Members in Growth and Product Division aged between 30 and 35:")
        for row in results:
            print(row)
    except Exception as error:
        print(f"Error querying team members in Growth and Product Division aged 30-35: {error}")
    finally:
        if cursor:
            cursor.close()
        if connection:
            connection.close()


def query_team_members_in_modules_1_3_5():
    try:
        connection = connect_to_db()
        cursor = connection.cursor()
        cursor.execute("""
            SELECT * FROM staff_info
            WHERE Module IN (1, 3, 5)
        """)
        results = cursor.fetchall()
        print("Team Members in Modules 1, 3, and 5:")
        for row in results:
            print(row)
    except Exception as error:
        print(f"Error querying team members in Modules 1, 3, and 5: {error}")
    finally:
        if cursor:
            cursor.close()
        if connection:
            connection.close()


def query_team_members_in_module_4_and_product():
    try:
        connection = connect_to_db()
        cursor = connection.cursor()
        cursor.execute("""
            SELECT * FROM staff_info
            WHERE Module = 4 OR Division = 'Product'
        """)
        results = cursor.fetchall()
        print("Team Members in Module 4 and Product Division:")
        for row in results:
            print(row)
    except Exception as error:
        print(f"Error querying team members in Module 4 and Product Division: {error}")
    finally:
        if cursor:
            cursor.close()
        if connection:
            connection.close()


# Run the queries
query_team_members_in_revenue()
query_team_members_in_growth_and_product_age_30_35()
query_team_members_in_modules_1_3_5()
query_team_members_in_module_4_and_product()
# Out:
# Connection to PostgreSQL successful
# Error creating database: database "paystack_team" already exists
#
# Connection to paystack_team DB successful
# Table staff_info created successfully
# Data inserted successfully
# Team Members in Revenue Division:
# ('Bolaji Akande', 'Revenue', 30, 3)
# ('Ijeoma Opara', 'Revenue', 26, 2)
# ('Dapo Awobokun', 'Revenue', 35, 2)
# ('Charles Idem', 'Revenue', 38, 3)
# Team Members in Growth and Product Division aged between 30 and 35:
# ('Seike Ibojo', 'Growth', 33, 4)
# ('Emmanuel Quartey', 'Growth', 31, 1)
# ('Awatt Bassey', 'Growth', 32, 2)
# ('King Makanjuola', 'Product', 31, 1)
# ('Dipo Omobomi', 'Product', 32, 1)
# ('Ayobami Alo', 'Product', 34, 1)
# Team Members in Modules 1, 3, and 5:
# ('Oyinda Aina', 'Business', 32, 1)
# ('Wale Eseyin', 'Engineering', 28, 3)
# ('Onyekachi Mbaike', 'Design', 37, 5)
# ('Opemipo Aikomo', 'Design', 28, 1)
# ('Ezra Olubi', 'Product', 30, 3)
# ('Alexander Fasoro', 'Engineering', 35, 1)
# ('Loknan Nanyak', 'Engineering', 44, 5)
# ('Fisayo Kolawole', 'Commercial', 27, 5)
# ('Emmanuel Quartey', 'Growth', 31, 1)
# ('Bolaji Akande', 'Revenue', 30, 3)
# ('King Makanjuola', 'Product', 31, 1)
# ('Dipo Omobomi', 'Product', 32, 1)
# ('Charles Idem', 'Revenue', 38, 3)
# ('Ayobami Alo', 'Product', 34, 1)
# Team Members in Module 4 and Product Division:
# ('Khadijah Abu', 'Product', 30, 2)
# ('Seike Ibojo', 'Growth', 33, 4)
# ('Ezra Olubi', 'Product', 30, 3)
# ('Ibrahim Lawal', 'Engineering', 39, 4)
# ('King Makanjuola', 'Product', 31, 1)
# ('Dipo Omobomi', 'Product', 32, 1)
# ('Ayobami Alo', 'Product', 34, 1)
