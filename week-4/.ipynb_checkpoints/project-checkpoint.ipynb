# %%
import tkinter as tk
from tkinter import messagebox

# Employee data
employees = {
    "Oluwatamilore ADENIRAN": {"department": "Logistics"},
    "Ayomide ADEWUMI": {"department": "Accounting"},
    "Oshim ADOH-AJAGBE": {"department": "Delivery"},
    "Chukwunonye AGBAKURU-NWOGU": {"department": "Accounting"},
    "Chiemeziem AGBAKWURU": {"department": "Logistics"},
    "Oluwatimehin AKINDE": {"department": "Accounting"},
    "Osose ARNIKA": {"department": "Logistics"},
    "Daniel ATELLY": {"department": "Delivery"},
    "Onyekachi AZOGU": {"department": "Delivery"},
    "Shalom BETURE": {"department": "Delivery"},
    "Nedi CHUKWUMA": {"department": "Logistics"},
    "Stephanie EBI": {"department": "Accounting"},
    "Jason EGBORO": {"department": "Administration"},
    "Edward EJEDIMU": {"department": "Delivery"},
    "Otu ELERI": {"department": "Administration"},
    "Onyinyechi EZE": {"department": "Administration"},
    "Makuochukwu EZEONYE": {"department": "Logistics"},
    "Moyosore GIWA": {"department": "Logistics"},
    "Ayonete ICHA": {"department": "Accounting"},
    "Eche IKPATI": {"department": "Accounting"},
    "Michael ILOENYOSI": {"department": "Delivery"},
    "Oluwadamilola IYAWE": {"department": "Delivery"},
    "Chijindu NWOKOLO": {"department": "Logistics"},
    "Joseph NWOTOKUBO": {"department": "Logistics"},
    "Daisy OBASOGIE": {"department": "Accounting"},
    "Samuel OBI": {"department": "Accounting"},
    "Betha OBIALOR": {"department": "Accounting"},
    "Boluwatife OGBONNA": {"department": "Delivery"},
    "Mary OIGBOCHIE": {"department": "Delivery"},
    "Raphael OKOCHA-OJEAH": {"department": "Administration"},
    "Victor OKOLO": {"department": "Administration"},
    "Derek OKORO": {"department": "Logistics"},
    "Akorede OLOWOKERE": {"department": "Accounting"},
    "Rasheed OLUBUADE": {"department": "Accounting"},
    "Daniel OSEMEKE": {"department": "Accounting"},
    "Mary-Cynthia OSSAI": {"department": "Logistics"},
    "Owoede PETER": {"department": "Logistics"},
    "Oluwafikunmi QUADRI": {"department": "Delivery"},
    "Uchenna UDE-IBE": {"department": "Delivery"},
    "Ejike UMEH": {"department": "Administration"}
}


def check_employee():
    first_name = first_name_entry.get().strip().capitalize()
    surname = surname_entry.get().strip().upper()
    department = department_entry.get().strip()
    full_name = f"{first_name} {surname}"

    if full_name in employees and employees[full_name]["department"] == department:
        messagebox.showinfo("Welcome", f"Welcome {full_name}!")
        department_members = [emp.split(" ")[1] for emp in employees if employees[emp]["department"] == department]
        messagebox.showinfo("Department Members",
                            f"Other members of {department} department:\n{', '.join(department_members)}")
    else:
        messagebox.showerror("Error", "Employee does not exist or incorrect department.")


# main window
root = tk.Tk()
root.geometry("500x300")
root.title("Employee Verification")

#labels and entry fields
first_name_label = tk.Label(root, text="First Name:")
first_name_label.pack()
first_name_entry = tk.Entry(root)
first_name_entry.pack()

surname_label = tk.Label(root, text="Surname:")
surname_label.pack()
surname_entry = tk.Entry(root)
surname_entry.pack()

department_label = tk.Label(root, text="Department:")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()

#submit button
submit_button = tk.Button(root, text="Check Employee", command=check_employee)
submit_button.pack()

root.mainloop()
